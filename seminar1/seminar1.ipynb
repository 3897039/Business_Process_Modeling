# %% [markdown]
# Пропишите простыми словами ключевые отличия бизнес-модели от операционной;
# Перечислите самые важные, на ваш взгляд, элементы операционной модели и аргументируйте свой выбор.

# %% [markdown]
# Операционная модель служит zdkztnczосновой, которая cdzpsdftn бизнес-процессы, ресурсы и технологии для достижения желаемых результатов.

# %% [markdown]
# Операционная модель включает в себя бизнес-процессы, организационную структуру, технологии, людей, документацию.

# %% [markdown]
# Разница между бизнес-моделью и операционной моделью  в их направлении и мобъёёме. Бизнес-модель описывает, как компания создает, поставляет и получает продукт. Он охватывает общую стратегию бизнеса.
#
# Операционная модель более конкретна и сконцентрирована на реализации своей бизнес-модель. Бизнес-модель является базой для создания основы компании. Но как бизнес-модель будет реализовываться определяет операционная модель.
